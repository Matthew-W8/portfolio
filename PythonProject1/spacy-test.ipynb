# %% [markdown]
# # Spacy Test
# Attempting to test spacy on project code (except our project code is still stuck in html), so I'm going to use a downloaded .txt file as a substitute.

# %%
import spacy

# %%
# nlp = spacy.cli.download("en_core_web_lg")
nlp = spacy.load("en_core_web_lg")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
filepath = 'xwing.txt'
f = open(filepath, 'r', encoding='utf8').read()

# %%
spacyRead = nlp(f)
for token in spacyRead:
    print(token.text, "---->", token.pos_, ":::::", token.lemma_)
# Out:
#     ----> SPACE :::::
# XWING ----> PROPN ::::: XWING
# FIGHTER ----> NOUN ::::: fighter
# TRAINER ----> NOUN ::::: trainer
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# Mega ----> ADJ ::::: mega
# Do ----> AUX ::::: do
# - ----> PUNCT ::::: -
# Da ----> PROPN ::::: Da
# Version ----> PROPN ::::: Version
# ) ----> PUNCT ::::: )
#
#                                 ----> SPACE :::::
#
# By ----> ADP ::::: by
# Network ----> PROPN ::::: Network
#
#                           ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# Not ----> PART ::::: not
# Quite ----> ADJ ::::: quite
# ) ----> PUNCT ::::: )
# V1ANDONLY ----> NUM ::::: v1andonly
#
#                                    ----> SPACE :::::
#
# and ----> CCONJ ::::: and
#
#                             ----> SPACE :::::
#
# Bonus ----> PROPN ::::: Bonus
# Crack ----> PROPN ::::: Crack
# - ----> PUNCT ::::: -
# Patch ----> PROPN ::::: Patch
#
#
#
#   ----> SPACE :::::
#
#
#
# Da ----> PROPN ::::: Da
# ...

# %%
spacy.explain("VERB")
# Out:
# 'verb'

# %% [markdown]
# Attempting to use spacy to define a collection and output.

# %%
def wordCollector(words):
    wordList = []
    count = 0
    for token in words:
        if token.pos_ == "PROPN":
            count += 1
            wordList.append(token.lemma_)
    return wordList
myWords = wordCollector(spacyRead)
print(myWords)
# Out:
# ['XWING', 'Da', 'Version', 'Network', 'Bonus', 'Crack', 'Patch', 'Da', 'Story', 'Good', 'GOD!This', 'Dark', 'Knight', 'Martial', 'Artist', 'Nice', "Don't", 'Shade', 'Bobs', 'me(fall', 'TRC', 'Origin', 'Ken', ').The', 'Copylocked', 'same(learn', 'Lucasfilm', 'OWN', 'Da', 'Trainer', 'Trainer', 'Training', 'ESC', 'Invunerabilty', 'Unlimited', 'Weapons', 'Starship', 'Collisions', 'Pilot', 'Ground', 'Excedrin', "I've", 'In', 'Game', 'save', 'game.(Hex', 'youur', 'Da', 'Controls', 'F7', 'Timex', 'Timer', 'Trainer', 'Tickin', 'Press', 'zero.(I', 'hope', 'hehe', 'F8', 'ESC', 'Beware!If', 'RESET.This', 'Damage', 'Map', 'Briefing', 'ESC', 'ON', 'ALT', 'N', 'NUMBERPAD', "Don't", 'Multiple', 'Manic', 'Mission', 'Madness', 'Trainer', 'Trainer', 'MODE.Some', 'DOS.(which', 'Key', 'TOURS.If', 'TOUR.This', 'Trainer', 'STARBASE', 'NEW', 'MISSION', 'MISSION', 'TOUR', 'Briefing', 'TOUR', 'Briefing', 'Room', 'SUCCESS', 'Briefing', 'Room', 'Room', 'Briefing', 'Room', 'Briefing', 'Room', 'Capeche', 'Input'
# ...

# %%
o = open("spaceyOutput.txt", "w")
o.write(wordCollector(words))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 o = open("spaceyOutput.txt", "w")
# ----> 2 o.write(wordCollector(words))
#
# NameError: name 'words' is not defined

# %% [markdown]
# Two ending thoughts:
# 1. What is the variable I have to call to make box [13] work?
# 2. How do I remove or minimize a cell's output because this was kind of a pain to work with because of the large opened outputs.
